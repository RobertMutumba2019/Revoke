# %%
import numpy as np
from scipy import stats
dn=np.random.uniform(0.0,5.0,250)
print(dn)
# Out:
# [1.88337695 3.0592299  0.54305092 4.51353904 4.30878704 2.13570011
#  1.36686801 0.78480519 1.53690914 2.41692468 0.61151523 1.61657248
#  1.18339164 4.62712878 3.98741981 4.48843257 1.80204034 4.56855237
#  2.03617312 3.0147591  0.63364253 1.23307139 0.75389483 1.88541234
#  4.4066497  0.17928883 1.22764061 2.55263271 0.12698069 3.97613153
#  2.84957283 3.59498851 0.69702436 1.46090014 0.51420333 0.23469342
#  1.16458811 2.65860518 0.88924021 4.84427632 1.5584965  0.2746313
#  3.60974126 3.54146279 3.51515429 0.49706506 1.52560053 2.08786299
#  0.17759882 4.63696566 3.3817145  1.27884707 0.0825065  1.06491317
#  3.40378286 1.367972   2.433806   1.47405599 1.17029514 2.63291236
#  3.25234909 4.30421579 2.36173642 2.83173039 0.76881103 3.86436157
#  3.47841159 2.55946643 3.4401001  1.02700312 1.97180722 4.89355052
#  3.24635241 4.21402614 0.03871552 1.54337058 4.70127287 3.9281149
#  2.29075613 2.43657355 2.84696145 1.45964977 4.62131341 2.72128795
#  3.15702721 0.7824844  2.34859536 0.464741   3.69925315 1.18250823
#  1.82276183 1.59485591 2.2222076  1.48178464 2.6050931  4.02686903
#  0.34568605 1.88297122 2.23761623 1.15228902 2.74494814 3.00667922
#  1.08847789 0.21992472 4.78349137 3.15736001 3.99709216 1.41288466
#  0.40616397 0.982898   3.32592333 2.60454967 0.07745808 2.40622586
#  0.25934164 3.66238146 1.15007462 4.28833711 4.2925956  2.3149768
#  1.07891853 1.44367528 0.22378648 1.51294044 0.74845046 1.85959701
#  4.13879723 4.81557659 0.1740419  4.36870948 4.39771491 4.07276714
#  1.33447321 0.50254766 1.83769714 4.24226965 2.62271348 2.3470432
#  2.34245293 2.94712729 2.03726911 1.60393955 2.10735582 2.6127691
#  1.10743909 1.89120345 1.71998196 1.6458846  1.74668547 2.86790344
#  4.24144892 2.73757623 2.30698491 3.71704981 3.29946044 2.00589316
#  0.30835794 1.12396353 4.64310228 3.94120012 4.9820111  4.64600742
#  2.35732445 0.94966892 4.95755972 3.31847514 3.03830703 0.71742295
#  2.55329272 2.05869882 1.87701876 4.6682913  4.63339549 0.21291266
#  1.52096746 1.80332353 2.09689735 0.08621927 4.78746446 3.01449244
#  0.85649292 0.54577141 0.52800716 3.39628209 0.11236399 2.11835012
#  1.46828383 0.04308817 4.28551832 4.94072269 4.12801198 3.09061917
#  4.67498379 4.51421371 3.72810893 1.0709292  1.82646023 4.49193834
#  1.8864619  3.09597044 0.15234303 1.69383176 0.37830562 3.42447257
#  1.50102532 3.73891508 3.89792347 3.74139998 3.80894341 4.94760379
#  4.16364265 3.9447211  1.67084903 4.47597062 3.60471571 3.33786422
#  2.70189799 1.45561046 2.26962557 0.23477084 2.36032579 4.74578008
#  2.74115966 3.56872774 0.18359402 1.06911027 4.60235618 1.84203814
#  2.74501313 2.63234624 3.68950499 3.0452666  2.99349478 4.04407236
#  1.18236236 1.80983137 2.14816427 3.56537238 3.90516771 2.43874321
#  3.59466415 0.19846544 1.69361065 3.39117911 4.6314955  2.74151468
#  3.68429287 1.40189069 1.39093464 2.79046762]

# %%
# Save to a CSV file
np.savetxt("dataset.csv", dn, delimiter=",", header="RandomValues", comments="")

print("Dataset saved to dataset.csv")
# Out:
# Dataset saved to dataset.csv

# %%
import matplotlib.pyplot as plt


plt.hist(dn, 5)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 slope, intercept, r, p, std_err = stats.linregress(x, y)
#       2 def myfunc(x):
#       3   return slope * x + intercept
#
# NameError: name 'stats' is not defined
