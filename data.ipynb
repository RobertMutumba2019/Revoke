# %%
import numpy as np
from scipy import stats
dn=np.random.uniform(0.0,5.0,250)
print(dn)
# Out:
# [4.5805795  4.49497358 3.27752176 4.58132449 2.87822421 4.18922322
#  3.7718187  0.28939128 3.75057809 3.95323973 1.42592318 3.21155514
#  4.97354711 4.14457444 3.69068053 2.34983732 4.32037662 4.07851982
#  1.69466776 1.30944587 4.65739847 4.62598701 1.24886911 3.29311589
#  2.54561064 0.52176812 0.74946825 1.91367381 0.41270938 0.20608046
#  3.91952452 2.11935401 0.90060531 4.6437495  2.37736515 4.30362301
#  0.05720036 0.24548241 2.39373382 1.60141999 2.90050066 2.57454693
#  1.04880021 2.25854798 1.91272403 3.04609946 0.2182001  1.83875172
#  3.33475762 2.13066939 2.20017439 4.96824687 3.51911567 2.55529771
#  3.08475156 1.86934838 0.94286323 2.48319127 4.44713378 2.34274977
#  3.06446999 2.11025244 1.19741484 4.41807304 0.9562978  3.33655675
#  3.64896346 2.647346   2.61445877 1.85156258 4.28374568 3.56695859
#  2.04341485 2.57381735 2.29476229 1.73549074 2.29077323 0.13434566
#  1.29739251 1.36165497 1.36634938 0.90217664 0.48558661 0.32454393
# ...

# %%
from sklearn.metrics import metrics

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 3))

print(metrics(y, mymodel(x)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.metrics import metrics
#       3 x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
#       4 y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
#
# ImportError: cannot import name 'metrics' from 'sklearn.metrics' (c:\Users\user\Desktop\Python\.venv\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
# Save to a CSV file
np.savetxt("dataset.csv", dn, delimiter=",", header="RandomValues", comments="")

print("Dataset saved to dataset.csv")
# Out:
# Dataset saved to dataset.csv

# %%
import matplotlib.pyplot as plt


plt.hist(dn, 5)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
actual = np.random.binomial(1,.9,size = 1000)
predicted = np.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])

cm_display.plot()
plt.show()

#The confusion matrix is used to assess and identify the errors in the model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 actual = np.random.binomial(1,.9,size = 1000)
#       2 predicted = np.random.binomial(1,.9,size = 1000)
# ----> 4 confusion_matrix = metrics.confusion_matrix(actual, predicted)
#       6 cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])
#       8 cm_display.plot()
#
# NameError: name 'metrics' is not defined

# %%
from sklearn.metrics import metrics

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 3))

print(metrics(y, mymodel(x)))
# Out:
# ---------------------------------------------------------------------------
#
# ImportError                               Traceback (most recent call last)
#
# Cell In[16], line 1
#
# ----> 1 from sklearn.metrics import metrics
#
#       3 x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
#
#       4 y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
#
#
#
# ImportError: cannot import name 'metrics' from 'sklearn.metrics' (c:\Users\user\Desktop\Python\.venv\Lib\site-packages\sklearn\metrics\__init__.py)
